# %%
from google_play_scraper import reviews, app
import pandas as pd
from datetime import datetime

# %%
banks = {
    "dashen": "com.dashen.dashensuperapp",
    "abyssinia": "com.boa.boaMobileBanking",
    "cbe": "com.combanketh.mobilebanking"
}

all_reviews = []

for bank_name, package_name in banks.items():
    print(f"Scraping reviews for {bank_name}...")
    bank_reviews, _ = reviews(
        package_name,
        count=500  
    )
    
    for r in bank_reviews:
        all_reviews.append({
            "review": r['content'],
            "rating": r['score'],
            "date": r['at'],
            "bank": bank_name,
            "source": "Google Play"
        })

print(f"Total reviews collected: {len(all_reviews)}")
# Out:
# Scraping reviews for dashen...
# Scraping reviews for abyssinia...
# Scraping reviews for cbe...
# Total reviews collected: 1500

# %%
df = pd.DataFrame(all_reviews)

# %%
df.drop_duplicates()
# Out:
#                                                  review  rating  \
# 0               very smart App easy to use and friendly       5
# 1                Very exemplery App to other Bank Aps !       5
# 2                                                  good       5
# 3                                  It Is An Amazing app       4
# 4     its fast and easy to communicate to the app an...       5
# ...                                                 ...     ...
# 1495                                            so good       5
# 1496                                   worst experience       1
# 1497                                 The 1st one is CBE       5
# 1498                                          excellent       5
# 1499                                               nice       5
#
#                     date    bank       source
# 0    2025-11-29 16:22:04  dashen  Google Play
# 1    2025-11-29 02:45:26  dashen  Google Play
# 2    2025-11-29 00:38:53  dashen  Google Play
# 3    2025-11-28 09:44:21  dashen  Google Play
# 4    2025-11-26 18:02:58  dashen  Google Play
# ...                  ...     ...          ...
# 1495 2025-08-04 19:31:09     cbe  Google Play
# 1496 2025-08-04 18:38:19     cbe  Google Play
# 1497 2025-08-04 18:21:22     cbe  Google Play
# 1498 2025-08-04 18:09:46     cbe  Google Play
# 1499 2025-08-04 17:47:35     cbe  Google Play
#
# [1500 rows x 5 columns]

# %%
print(df.isna().sum())
df.dropna(subset=['review', 'rating', 'date'], inplace=True)
# Out:
# review    0
# rating    0
# date      0
# bank      0
# source    0
# dtype: int64

# %%
df['date'] = df['date'].apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
df.drop_duplicates()
# Out:
#                                                  review  rating        date  \
# 0               very smart App easy to use and friendly       5  2025-11-29
# 1                Very exemplery App to other Bank Aps !       5  2025-11-29
# 2                                                  good       5  2025-11-29
# 3                                  It Is An Amazing app       4  2025-11-28
# 4     its fast and easy to communicate to the app an...       5  2025-11-26
# ...                                                 ...     ...         ...
# 1495                                            so good       5  2025-08-04
# 1496                                   worst experience       1  2025-08-04
# 1497                                 The 1st one is CBE       5  2025-08-04
# 1498                                          excellent       5  2025-08-04
# 1499                                               nice       5  2025-08-04
#
#         bank       source
# 0     dashen  Google Play
# 1     dashen  Google Play
# 2     dashen  Google Play
# 3     dashen  Google Play
# 4     dashen  Google Play
# ...      ...          ...
# 1495     cbe  Google Play
# 1496     cbe  Google Play
# 1497     cbe  Google Play
# 1498     cbe  Google Play
# 1499     cbe  Google Play
#
# [1490 rows x 5 columns]

# %%
df.to_csv("bank_reviews.csv")
print("CSV saved successfully!")
# Out:
# CSV saved successfully!
